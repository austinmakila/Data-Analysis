# %%
import pandas as pd
import numpy as np
import missingno as msno
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\AUSTIN\\Desktop\\python'

# %%
data=pd.read_csv(r'C:\Users\AUSTIN\Desktop\python\data_project.csv')
data.head()
# Out:
#                            start                            end        Date  \
# 0  2021-11-08T22:11:21.965+03:00  2021-11-08T22:14:17.796+03:00  08/11/2021
# 1  2021-11-08T22:37:28.773+03:00  2021-11-08T22:44:38.296+03:00  08/11/2021
# 2  2021-11-08T22:27:50.106+03:00  2021-11-09T00:23:03.588+03:00  08/11/2021
# 3  2021-11-08T21:52:37.504-08:00  2021-11-08T21:55:25.834-08:00  07/11/2021
# 4  2021-11-09T10:16:39.622+03:00  2021-11-09T10:22:31.259+03:00  09/11/2021
#
#    intro  Note_2  Gender  Age grp1._3_Date_of_interview grp_2.mobile  \
# 0    NaN     NaN       0   20                       NaN            1
# 1    NaN     NaN       0   20                       NaN            1
# 2    NaN     NaN       1   24                       NaN        1 2 3
# 3    NaN     NaN       1   23                       NaN            1
# 4    NaN     NaN       0   21                       NaN            1
#
#    grp_2.mobile.1  ...             __version__  \
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Gender', 'Age', 'Primary_line', 'Rating', 'Duration_p.line',
#        'Satistifaction_p.line', 'pre_usage', 'Job_status', 'Monthly_income',
#        'cost_line', 'monthly_exp', 'rate_service', 'service_expectations',
#        'service_clarity', 'lte_type', 'connectivity_satisfaction',
#        'signal_strength_problems', 'promotion_considered',
#        'factors_influenced'],
#       dtype='object')

# %%
data.columns.tolist()

# %%
data=data.loc[:,['Date', 'Gender', 'Age', 'Primary_line', 'Rating', 'Duration_p.line', 'Satistifaction_p.line',
                     'pre_usage', 'Job_status', 'Monthly_income', 'cost_line','monthly_exp',
                     'rate_service', 'service_expectations', 'service_clarity', 'lte_type',
  'connectivity_satisfaction','signal_strength_problems', 'promotion_considered', 'factors_influenced']]

data.head()
# Out:
#          Date  Gender  Age Primary_line  Rating  Duration_p.line  \
# 0  08/11/2021       0   20       Telkom       4              NaN
# 1  08/11/2021       0   20    Safaricom       4              NaN
# 2  08/11/2021       1   24    Safaricom       4              NaN
# 3  07/11/2021       1   23    Safaricom       3              NaN
# 4  09/11/2021       0   21    Safaricom       4              NaN
#
#    Satistifaction_p.line pre_usage  Job_status Monthly_income  cost_line  \
# 0                      1       NaN         3.0            NaN        NaN
# 1                      1       NaN         4.0            NaN        NaN
# 2                      1       NaN         1.0            NaN        NaN
# 3                      2       NaN         4.0            NaN        NaN
# 4                      1       NaN         4.0            NaN        NaN
#
#    monthly_exp  rate_service  service_expectations  service_clarity lte_type  \
# ...

# %%
data.shape
# Out:
# (378, 20)

# %%
data.isnull().sum()
# Out:
# Date                           0
# Gender                         0
# Age                            0
# Primary_line                   0
# Rating                         0
# Duration_p.line               58
# Satistifaction_p.line          0
# pre_usage                     58
# Job_status                     6
# Monthly_income               182
# cost_line                     58
# monthly_exp                    0
# rate_service                   0
# service_expectations           0
# service_clarity                0
# lte_type                       0
# connectivity_satisfaction      0
# signal_strength_problems       0
# promotion_considered           0
# factors_influenced           137
# dtype: int64

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(data)
# Out:
# <AxesSubplot:>

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent', 
                        missing_values=np.nan)
imputer = imputer.fit(data)
data.iloc[:,:] = imputer.transform(data)
data
# Out:
#            Date  Gender  Age Primary_line  Rating  Duration_p.line  \
# 0    08/11/2021       0   20       Telkom       4              3.0
# 1    08/11/2021       0   20    Safaricom       4              3.0
# 2    08/11/2021       1   24    Safaricom       4              3.0
# 3    07/11/2021       1   23    Safaricom       3              3.0
# 4    09/11/2021       0   21    Safaricom       4              3.0
# ..          ...     ...  ...          ...     ...              ...
# 373  12/01/2022       1   25    Safaricom       4              6.0
# 374  11/01/2022       0   45    Safaricom       5              7.0
# 375  12/01/2022       1   51    Safaricom       5              8.0
# 376  12/01/2022       1   43    Safaricom       5              9.0
# 377  12/01/2022       0   47    Safaricom       5              7.0
#
#      Satistifaction_p.line pre_usage  Job_status   Monthly_income  cost_line  \
# 0                        1         1         3.0  10_000___30_000      100.0
# ...

# %%
data.isnull().sum()
# Out:
# Date                         0
# Gender                       0
# Age                          0
# Primary_line                 0
# Rating                       0
# Duration_p.line              0
# Satistifaction_p.line        0
# pre_usage                    0
# Job_status                   0
# Monthly_income               0
# cost_line                    0
# monthly_exp                  0
# rate_service                 0
# service_expectations         0
# service_clarity              0
# lte_type                     0
# connectivity_satisfaction    0
# signal_strength_problems     0
# promotion_considered         0
# factors_influenced           0
# dtype: int64

# %%
data['pre_usage']=data['pre_usage'].replace(['1 2','3 1','1 3','3'],[3,3,3,3])
data.pre_usage.value_counts()
# Out:
# 1    235
# 3    122
# 2     21
# Name: pre_usage, dtype: int64

# %%
data['Primary_line']=data['Primary_line'].replace(['airtel','Airtel/Safaricom'],['Airtel','Airtel'])

data['Primary_line']=data['Primary_line'].replace(['Telcomm'],['Telkom'])
data['Primary_line']=data['Primary_line'].replace(['safcom'],['Safaricom'])
data['Primary_line']=data['Primary_line'].replace(['Telcom'],['Telkom'])





data.Primary_line.value_counts()
# Out:
# Safaricom    306
# Airtel        44
# Telkom        22
# Equitel        6
# Name: Primary_line, dtype: int64

# %%
data['lte_type']=data['lte_type'].replace(['2 3','1 2','1 2 3','2 1','3 2','4 3','2 3 1','3 4','4','2','3'],[3,3,3,2,3,4,3,4,4,2,3])
data.lte_type.value_counts()
# Out:
# 3    196
# 2    145
# 4     25
# 1     12
# Name: lte_type, dtype: int64

# %%
data['pre_usage']=data['pre_usage'].replace(['1 2','1 3','3 1','3','2'],[2,3,3,3,2])
data.pre_usage.value_counts()
# Out:
# 1    235
# 3    122
# 2     21
# Name: pre_usage, dtype: int64

# %%
data['Monthly_income']=data['Monthly_income'].replace(['10_000___30_000','__10_000','30_001___50_000','__50_000'],
                                                  ['10000-30000','<10000','30001-50000','>50000'])
data.Monthly_income.value_counts()
# Out:
# 10000-30000    266
# <10000          52
# 30001-50000     43
# >50000          17
# Name: Monthly_income, dtype: int64

# %%
data.head()
# Out:
#          Date  Gender  Age Primary_line  Rating  Duration_p.line  \
# 0  08/11/2021       0   20       Telkom       4              3.0
# 1  08/11/2021       0   20    Safaricom       4              3.0
# 2  08/11/2021       1   24    Safaricom       4              3.0
# 3  07/11/2021       1   23    Safaricom       3              3.0
# 4  09/11/2021       0   21    Safaricom       4              3.0
#
#    Satistifaction_p.line pre_usage  Job_status Monthly_income  cost_line  \
# 0                      1         1         3.0    10000-30000      100.0
# 1                      1         1         4.0    10000-30000      100.0
# 2                      1         1         1.0    10000-30000      100.0
# 3                      2         1         4.0    10000-30000      100.0
# 4                      1         1         4.0    10000-30000      100.0
#
#    monthly_exp  rate_service  service_expectations  service_clarity lte_type  \
# ...

# %%
data.Rating.value_counts()
data['Satistifaction_p.line'].value_counts()
data.factors_influenced.value_counts()
# Out:
# 2              175
# 3               37
# 4               27
# 1 2 3 4 5 6     23
# 5               19
# 6               16
# 1 2 3 4 5       14
# 1               13
# 2 3              7
# 7                4
# 4 5              4
# 3 2              3
# 2 4              3
# 4 3              2
# 1 2 3 5          2
# 5 6              1
# 1 2 3            1
# 5 4 3            1
# 5 4              1
# 4 2              1
# 6 3              1
# 5 3              1
# 5 2              1
# 1 2 3 4          1
# 4 7              1
# 6 4              1
# 4 3 5            1
# 5 3 2            1
# 1 2 5            1
# 1 2 3 4 6        1
# 1 3 4 5          1
# 3 5              1
# 3 2 5            1
# 1 2              1
# 2 6              1
# 2 5              1
# 2 3 6            1
# 2 3 4 5          1
# 2 3 4            1
# 2 1 5            1
# 2 1 3            1
# 2 1              1
# 1 3 5 6          1
# 3 6              1
# Name: factors_influenced, dtype: int64

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       378 non-null    object
#  1   Gender                     378 non-null    int64
#  2   Age                        378 non-null    int64
#  3   Primary_line               378 non-null    object
#  4   Rating                     378 non-null    int64
#  5   Duration_p.line            378 non-null    float64
#  6   Satistifaction_p.line      378 non-null    int64
#  7   pre_usage                  378 non-null    object
#  8   Job_status                 378 non-null    float64
#  9   Monthly_income             378 non-null    object
#  10  cost_line                  378 non-null    float64
#  11  monthly_exp                378 non-null    int64
#  12  rate_service               378 non-null    int64
# ...

# %%
data.columns.tolist()
# Out:
# ['Date',
#  'Gender',
#  'Age',
#  'Primary_line',
#  'Rating',
#  'Duration_p.line',
#  'Satistifaction_p.line',
#  'pre_usage',
#  'Job_status',
#  'Monthly_income',
#  'cost_line',
#  'monthly_exp',
#  'rate_service',
#  'service_expectations',
#  'service_clarity',
#  'lte_type',
#  'connectivity_satisfaction',
#  'signal_strength_problems',
#  'promotion_considered',
#  'factors_influenced']

# %%
cols_categorical=[
'Gender',
 'Primary_line',
 'Rating',
 'Duration_p.line',
 'Satistifaction_p.line',
 'pre_usage',
 'Job_status',
 'Monthly_income',
 'monthly_exp',
 'rate_service',
 'service_expectations',
 'service_clarity',
 'lte_type',
 'connectivity_satisfaction',
 'signal_strength_problems',
 'promotion_considered',
 'factors_influenced']

# %%
for col in cols_categorical:
    data[col] = data[col].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       378 non-null    object
#  1   Gender                     378 non-null    category
#  2   Age                        378 non-null    int64
#  3   Primary_line               378 non-null    category
#  4   Rating                     378 non-null    category
#  5   Duration_p.line            378 non-null    category
#  6   Satistifaction_p.line      378 non-null    category
#  7   pre_usage                  378 non-null    category
#  8   Job_status                 378 non-null    category
#  9   Monthly_income             378 non-null    category
#  10  cost_line                  378 non-null    float64
#  11  monthly_exp                378 non-null    category
#  12  rate_service               378 non-null    category
# ...

# %%
data.Primary_line.value_counts().sort_index(ascending=False).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
from pandas import DataFrame , read_csv



rating_count  = data['Rating'].value_counts()
rating_count = rating_count[:5,]
plt.figure(figsize=(10,5))
sns.barplot(rating_count.index, rating_count.values, alpha=0.8)
plt.title('Starbucks in top 10 cities in the World')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Rating', fontsize=12)
plt.show()
# Out:
# C:\Users\AUSTIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
(ggplot(mtcars, aes(fill='factor(cyl)', y='mpg', x='factor(carb)')) + 
    geom_bar(position="stack", stat="identity") +
    #scale_fill_viridis(discrete = T) +
    ggtitle("Studying 4 species..") +
    #theme_ipsum() +
    xlab(""))

# %%
data.head()
# Out:
#          Date Gender  Age Primary_line Rating Duration_p.line  \
# 0  08/11/2021      0   20       Telkom      4             3.0
# 1  08/11/2021      0   20    Safaricom      4             3.0
# 2  08/11/2021      1   24    Safaricom      4             3.0
# 3  07/11/2021      1   23    Safaricom      3             3.0
# 4  09/11/2021      0   21    Safaricom      4             3.0
#
#   Satistifaction_p.line pre_usage Job_status Monthly_income  cost_line  \
# 0                     1         1        3.0    10000-30000      100.0
# 1                     1         1        4.0    10000-30000      100.0
# 2                     1         1        1.0    10000-30000      100.0
# 3                     2         1        4.0    10000-30000      100.0
# 4                     1         1        4.0    10000-30000      100.0
#
#   monthly_exp rate_service service_expectations service_clarity lte_type  \
# 0           4            2                    1               2        3
# ...

# %%
data1=data[['Date','Job_status','pre_usage','monthly_exp','Primary_line','cost_line','Age','Monthly_income']]
data1
# Out:
#            Date Job_status pre_usage monthly_exp Primary_line  cost_line  Age  \
# 0    08/11/2021        3.0         1           4       Telkom      100.0   20
# 1    08/11/2021        4.0         1           4    Safaricom      100.0   20
# 2    08/11/2021        1.0         1           3    Safaricom      100.0   24
# 3    07/11/2021        4.0         1           2    Safaricom      100.0   23
# 4    09/11/2021        4.0         1           3    Safaricom      100.0   21
# ..          ...        ...       ...         ...          ...        ...  ...
# 373  12/01/2022        4.0         3           3    Safaricom      100.0   25
# 374  11/01/2022        1.0         1           3    Safaricom      100.0   45
# 375  12/01/2022        2.0         3           3    Safaricom      120.0   51
# 376  12/01/2022        1.0         1           3    Safaricom      120.0   43
# 377  12/01/2022        1.0         1           3    Safaricom      100.0   47
#
#     Monthly_income
# ...

# %%
tempsmelt = pd.melt(data, id_vars=['Date','monthly_exp'], value_vars=['cost_line','Age'],

    var_name='variable_names', value_name='values' )
tempsmelt
# Out:
#            Date monthly_exp variable_names  values
# 0    08/11/2021           4      cost_line   100.0
# 1    08/11/2021           4      cost_line   100.0
# 2    08/11/2021           3      cost_line   100.0
# 3    07/11/2021           2      cost_line   100.0
# 4    09/11/2021           3      cost_line   100.0
# ..          ...         ...            ...     ...
# 751  12/01/2022           3            Age    25.0
# 752  11/01/2022           3            Age    45.0
# 753  12/01/2022           3            Age    51.0
# 754  12/01/2022           3            Age    43.0
# 755  12/01/2022           3            Age    47.0
#
# [756 rows x 4 columns]

# %%
(ggplot(tempsmelt,aes('monthly_exp','values',fill='variable_names'))
 + geom_col(position='fill')
 #+ scale_x_continuous(breaks=months)
 + theme_light()
)
# Out:
# <ggplot: (122955008651)>

# %%
(ggplot(data,aes('Monthly_income','Age',fill='Primary_line'))
 + geom_col(position='fill')+
 facet_wrap('Job_status')
 #+ scale_x_continuous(breaks=months)
 + theme_light()
)
# Out:
# <ggplot: (122956047737)>

# %%
data1.groupby(['Primary_line','Monthly_income'])['cost_line'].mean()
# Out:
# Primary_line  Monthly_income
# Airtel        10000-30000        56.466667
#               30001-50000        37.500000
#               <10000             41.428571
#               >50000            150.000000
# Equitel       10000-30000        40.000000
#               30001-50000       100.000000
#               <10000            100.000000
#               >50000            100.000000
# Safaricom     10000-30000        97.331776
#               30001-50000       108.684211
#               <10000             90.756098
#               >50000            100.000000
# Telkom        10000-30000        42.631579
#               30001-50000              NaN
#               <10000             33.333333
#               >50000                   NaN
# Name: cost_line, dtype: float64

# %%
round(pd.crosstab([data1.Job_status,data1.Primary_line],[data1.monthly_exp,data1.pre_usage],normalize=True)*100,1).stack()

# %%
data1.columns
# Out:
# Index(['Job_status', 'pre_usage', 'monthly_exp', 'Primary_line', 'cost_line',
#        'Age', 'Monthly_income'],
#       dtype='object')

# %%
pd.crosstab([data.Primary_line,data.Monthly_income],[data.Job_status],values=data.Age,aggfunc=np.average)
# Out:
# Job_status                         1.0        2.0        3.0        4.0
# Primary_line Monthly_income
# Airtel       10000-30000     34.000000  35.444444  34.636364  28.250000
#              30001-50000     52.000000  35.333333        NaN        NaN
#              <10000                NaN  36.857143        NaN        NaN
#              >50000          52.000000  41.000000        NaN        NaN
# Equitel      10000-30000     37.000000        NaN  34.500000        NaN
#              30001-50000           NaN  33.000000        NaN        NaN
#              <10000                NaN  29.000000        NaN        NaN
#              >50000          38.000000        NaN        NaN        NaN
# Safaricom    10000-30000     35.395349  35.264706  36.705882  27.521739
#              30001-50000     38.909091  37.937500        NaN        NaN
#              <10000          30.500000  32.370370        NaN        NaN
#              >50000          40.222222  35.750000        NaN        NaN
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Gender', 'Age', 'Primary_line', 'Rating', 'Duration_p.line',
#        'Satistifaction_p.line', 'pre_usage', 'Job_status', 'Monthly_income',
#        'cost_line', 'monthly_exp', 'rate_service', 'service_expectations',
#        'service_clarity', 'lte_type', 'connectivity_satisfaction',
#        'signal_strength_problems', 'promotion_considered',
#        'factors_influenced'],
#       dtype='object')

# %%
data1[data1['cost_line']>=2016]
# Out:
#     Job_status pre_usage monthly_exp Primary_line  cost_line  Age  \
# 134        2.0         1           1       Airtel     3000.0   41
# 135        2.0         1           1       Airtel     3000.0   41
#
#     Monthly_income
# 134         >50000
# 135         >50000

# %%
data1[data1['cost_line']>=200]
# Out:
#     Job_status pre_usage monthly_exp Primary_line  cost_line  Age  \
# 72         2.0         3           3    Safaricom      250.0   42
# 73         2.0         2           3    Safaricom      300.0   40
# 114        3.0         1           1    Safaricom      200.0   41
# 121        2.0         3           2    Safaricom      200.0   26
# 126        2.0         3           4    Safaricom      200.0   26
# 132        3.0         3           1    Safaricom      200.0   43
# 134        2.0         1           1       Airtel      200.0   41
# 135        2.0         1           1       Airtel      200.0   41
# 142        4.0         1           4    Safaricom      200.0   22
# 160        1.0         3           2    Safaricom      300.0   31
# 200        1.0         1           4    Safaricom      200.0   24
# 204        3.0         1           3    Safaricom      200.0   24
# 270        2.0         3           3    Safaricom      200.0   45
# ...

# %%
data1['cost_line']=data1['cost_line'].replace([3000.00,1800.00,600.00],[200.00,200.00,200.00])

# %%
data.columns.tolist()
# Out:
# ['Date',
#  'Gender',
#  'Age',
#  'Primary_line',
#  'Rating',
#  'Duration_p.line',
#  'Satistifaction_p.line',
#  'pre_usage',
#  'Job_status',
#  'Monthly_income',
#  'cost_line',
#  'monthly_exp',
#  'rate_service',
#  'service_expectations',
#  'service_clarity',
#  'lte_type',
#  'connectivity_satisfaction',
#  'signal_strength_problems',
#  'promotion_considered',
#  'factors_influenced']
